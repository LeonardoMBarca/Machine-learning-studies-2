# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = '/Users/leona/OneDrive/Documentos/GitHub/Machine-learning-studies-2/ensemble/AdaBoost/exercise/school_grades_weca_dataset.csv'

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup fatherd  \
# 0  course   mother           2          2         0       yes     no      no
# 1  course   father           1          2         0        no    yes      no
# 2   other   mother           1          2         0       yes     no      no
# 3    home   mother           1          3         0        no    yes      no
# 4    home   father           1          2         0        no    yes      no
#
# ...

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# fatherd       0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
for i in df.columns:
    if df[i].dtypes == object and df[i].nunique() == 2:
        values = df[i].unique()
        df[i] = df[i].replace({values[0]: 0, values[1]: 1})
        print(i)
# Out:
# school
# sex
# address
# famsize
# Pstatus
# schoolsup
# famsup
# fatherd
# activities
# nursery
# higher
# internet
# romantic
# C:\Users\leona\AppData\Local\Temp\ipykernel_1200\1830227894.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[i] = df[i].replace({values[0]: 0, values[1]: 1})

# %%
for i in df.columns:
    if df[i].dtypes == object:
        display(df[i].value_counts(), i)
# Out:
# Mjob
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: count, dtype: int64
# 'Mjob'
# Fjob
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: count, dtype: int64
# 'Fjob'
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64
# 'reason'
# guardian
# mother    455
# father    153
# other      41
# Name: count, dtype: int64
# 'guardian'

# %%
df = pd.get_dummies(df, columns=['Mjob'], dtype=int)
df = pd.get_dummies(df, columns=['Fjob'], dtype=int)
df = pd.get_dummies(df, columns=['reason'], dtype=int)
df = pd.get_dummies(df, columns=['guardian'], dtype=int)

# %%
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0       0    0   18        0        0        0     4     4           2
# 1       0    0   17        0        0        1     1     1           1
# 2       0    0   15        0        1        1     1     1           1
# 3       0    0   15        0        0        1     4     2           1
# 4       0    0   16        0        0        1     3     3           1
#
#    studytime  failures  schoolsup  famsup  fatherd  activities  nursery  \
# 0          2         0          0       0        0           0        0
# 1          2         0          1       1        0           0        1
# 2          2         0          0       0        0           0        0
# 3          3         0          1       1        0           1        0
# 4          2         0          1       1        0           0        0
#
#    higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  health  \
# ...

# %%
df.shape
# Out:
# (649, 46)

# %%
df.dtypes
# Out:
# school               int64
# sex                  int64
# age                  int64
# address              int64
# famsize              int64
# Pstatus              int64
# Medu                 int64
# Fedu                 int64
# traveltime           int64
# studytime            int64
# failures             int64
# schoolsup            int64
# famsup               int64
# fatherd              int64
# activities           int64
# nursery              int64
# higher               int64
# internet             int64
# romantic             int64
# famrel               int64
# freetime             int64
# goout                int64
# Dalc                 int64
# Walc                 int64
# health               int64
# absences             int64
# G1                   int64
# G2                   int64
# G3                   int64
# Mjob_at_home         int32
# Mjob_health          int32
# Mjob_other           int32
# Mjob_services        int32
# Mjob_teacher         int32
# ...

# %%
x = df.drop('G3', axis=1)
y = df['G3']

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
strat = StratifiedKFold(n_splits=5, shuffle=True, random_state=15)

# %%
model = AdaBoostRegressor(n_estimators=100)
result = cross_val_score(model, x, y, cv=strat, n_jobs=-1)
print(f'The result of this model was: {result.mean()}')
# Out:
# c:\Users\leona\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# The result of this model was: 0.7819140363075744
